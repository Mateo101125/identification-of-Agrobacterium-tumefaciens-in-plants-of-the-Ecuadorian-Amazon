# %% [markdown]
# # Agrobacterium tumefaciens in Amazon Plant

# %%
# !pip install fastaparser #instalo el paquete fastaparser
# Out:
# ...
# sys:1: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x278d1131f40>
# ...
# C:\Users\Mateo\anaconda3\lib\site-packages\IPython\utils\_process_win32.py:124: ResourceWarning: unclosed file <_io.BufferedWriter name=4>
#   return process_handler(cmd, _system_body)
# ...
# C:\Users\Mateo\anaconda3\lib\site-packages\IPython\utils\_process_win32.py:124: ResourceWarning: unclosed file <_io.BufferedReader name=5>
#   return process_handler(cmd, _system_body)
# ...
# C:\Users\Mateo\anaconda3\lib\site-packages\IPython\utils\_process_win32.py:124: ResourceWarning: unclosed file <_io.BufferedReader name=6>
#   return process_handler(cmd, _system_body)
# ...

# %%
# !pip install Bio #instalo el paquete Bio
# Out:
# ...
# C:\Users\Mateo\anaconda3\lib\threading.py:914: ResourceWarning: unclosed file <_io.BufferedWriter name=4>
#   del self._target, self._args, self._kwargs
# ...
# C:\Users\Mateo\anaconda3\lib\threading.py:914: ResourceWarning: unclosed file <_io.BufferedReader name=5>
#   del self._target, self._args, self._kwargs
# ...
# C:\Users\Mateo\anaconda3\lib\threading.py:914: ResourceWarning: unclosed file <_io.BufferedReader name=6>
#   del self._target, self._args, self._kwargs
# ...
# sys:1: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x278d1275c40>
# ...

# %%
#importo los paquetes
import Bio
import fastaparser

# %%
### Agrobacterium tumefaciens strain 12D1 plasmid pAt12D1, complete sequence
from Bio import Entrez #importo el Entrez
from Bio import SeqIO #importo el SeqIO

Entrez.email = "A.N.Other@example.com"
handle=Entrez.efetch (db="nucleotide", rettype="fasta", retmode="text", id="NZ_CP033033.1")
record = SeqIO.read(handle, "fasta")
handle.close()
print(record.description)
print(record.seq)
Agro_sequence= record.seq
# Out:
# NZ_CP033033.1 Agrobacterium tumefaciens strain 12D1 plasmid pAt12D1, complete sequence
# ...

# %%
### Bixa orellana chromosome Chloroplast DNA
from Bio import Entrez #importo el Entrez
from Bio import SeqIO #importo el SeqIO

Entrez.email = "A.N.Other@example.com"
handle=Entrez.efetch (db="nucleotide", rettype="fasta", retmode="text", id="MH025909.1")
record = SeqIO.read(handle, "fasta")
handle.close()
print(record.description)
print(record.seq)
bixa_sequence= record.seq
# Out:
# MH025909.1 Bixa orellana chromosome Chloroplast DNA, complete genome
# ...

# %%
###Solanum tuberosum chloroplast
from Bio import Entrez
from Bio import SeqIO

Entrez.email = "A.N.Other@example.com"
handle=Entrez.efetch (db="nucleotide", rettype="fasta", retmode="text", id="NC_008096.2")
record= SeqIO.read(handle, "fasta")
handle.close()
print(record.description)
print(record.seq)
solanum_sequence= record.seq
# Out:
# NC_008096.2 Solanum tuberosum chloroplast, complete genome
# ...

# %%
###Manihot esculenta chloroplast
from Bio import Entrez
from Bio import SeqIO

Entrez.email = "A.N.Other@example.com"
handle=Entrez.efetch (db="nucleotide", rettype="fasta", retmode="text", id="NC_010433.1")
record= SeqIO.read(handle, "fasta")
handle.close()
print(record.description)
print(record.seq)
manihot_sequence= record.seq
# Out:
# NC_010433.1 Manihot esculenta chloroplast, complete genome
# ...

# %%
###Hevea brasiliensis chloroplast
from Bio import Entrez
from Bio import SeqIO

Entrez.email = "A.N.Other@example.com"
handle=Entrez.efetch (db="nucleotide", rettype="fasta", retmode="text", id=" NC_015308.1")
record= SeqIO.read(handle, "fasta")
handle.close()
print(record.description)
print(record.seq)
hevea_sequence= record.seq
# Out:
# NC_015308.1 Hevea brasiliensis chloroplast, complete genome
# ...

# %%
###A.tumefaciens beta-D-glucosidase (cbg-1) gene, complete cds
from Bio import Entrez
from Bio import SeqIO

Entrez.email = "A.N.Other@example.com"
handle=Entrez.efetch (db="nucleotide", rettype="fasta", retmode="text", id="M59852.1")
record= SeqIO.read(handle, "fasta")
handle.close()
print(record.description)
print(record.seq)
Agro_beta_D_glucosidase_secuence= record.seq
# Out:
# M59852.1 A.tumefaciens beta-D-glucosidase (cbg-1) gene, complete cds
# ...

# %%
###Plasmid Ti (from Agrobacterium tumefaciens, strain octopine-type R10) regulatory protein (traR) gene, complete cds
from Bio import Entrez
from Bio import SeqIO

Entrez.email = "A.N.Other@example.com"
handle=Entrez.efetch (db="nucleotide", rettype="fasta", retmode="text", id=" L08596.1")
record= SeqIO.read(handle, "fasta")
handle.close()
print(record.description)
print(record.seq)
Agro_octopine_type_R10_secuence= record.seq
# Out:
# L08596.1 Plasmid Ti (from Agrobacterium tumefaciens, strain octopine-type R10) regulatory protein (traR) gene, complete cds
# ...

# %%
###Agrobacterium rhizogenes strain A4 plasmid pRiA4, complete sequence 1478-1486
from Bio import Entrez
from Bio import SeqIO

Entrez.email = "A.N.Other@example.com"
handle=Entrez.efetch (db="nucleotide", rettype="fasta", retmode="text", id=" NZ_CP073113.1")
record= SeqIO.read(handle, "fasta")
handle.close()
print(record.description)
print(record.seq)
Agro_rhizogenes_secuence= record.seq
# Out:
# NZ_CP073113.1 Agrobacterium rhizogenes strain A4 plasmid pRiA4, complete sequence
# ...

# %%
len(Agro_sequence)
# Out:
# 160006

# %%
Agro_beta_D_glucosidase_secuence in Agro_sequence
# Out:
# False

# %%
Agro_octopine_type_R10_secuence in Agro_sequence
# Out:
# False

# %%
len(bixa_sequence)
# Out:
# 159708

# %%
len(solanum_sequence)
# Out:
# 155296

# %%
len(manihot_sequence)
# Out:
# 161453

# %%
len(hevea_sequence)
# Out:
# 161191

# %%
len(Agro_beta_D_glucosidase_secuence)
# Out:
# 3710

# %%
len(Agro_octopine_type_R10_secuence)
# Out:
# 1020

# %%
len(Agro_rhizogenes_secuence)
# Out:
# 245508

# %%
Agro_octopine_type_R10_secuence in bixa_sequence
# Out:
# False

# %%
Agro_octopine_type_R10_secuence in solanum_sequence
# Out:
# False

# %%
Agro_octopine_type_R10_secuence in manihot_sequence
# Out:
# False

# %%
Agro_octopine_type_R10_secuence in hevea_sequence
# Out:
# False

# %%
Agro_beta_D_glucosidase_secuence in bixa_sequence
# Out:
# False

# %%
Agro_beta_D_glucosidase_secuence in solanum_sequence
# Out:
# False

# %%
Agro_beta_D_glucosidase_secuence in manihot_sequence
# Out:
# False

# %%
Agro_beta_D_glucosidase_secuence in hevea_sequence
# Out:
# False

# %%
Agro_rhizogenes_secuence in bixa_sequence
# Out:
# False

# %%
Agro_rhizogenes_secuence in solanum_sequence
# Out:
# False

# %%
Agro_rhizogenes_secuence in manihot_sequence
# Out:
# False

# %%
Agro_rhizogenes_secuence in hevea_sequence
# Out:
# False
